# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.10 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.3/107.7 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Polyp
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Polyp'
# /content/drive/MyDrive/Polyp

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=dataset-yolo.yaml epochs=150 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.10 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=best.pt data=dataset-val-yolo.yaml
# Out:
# Ultralytics 8.3.10 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 13.5MB/s]
# val: Scanning /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/labels... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:40<00:00,  2.49it/s]
# val: New cache created: /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:39<00:00,  5.64s/it]
#                    all        100        101      0.924      0.957       0.97      0.797
# Speed: 15.9ms preprocess, 353.0ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/val12
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=val model=best.pt data=dataset-val-yolo.yaml

# %%
# !yolo task=detect mode=predict model=best.pt conf=0.5 source=Datasets/Kvasir-SEG/test/images save=True
# Out:
# Ultralytics 8.3.10 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/0.jpg: 640x640 1 polyp, 365.1ms
# image 2/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/1.jpg: 640x640 1 polyp, 463.5ms
# image 3/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/10.jpg: 640x640 1 polyp, 306.1ms
# image 4/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/11.jpg: 640x640 1 polyp, 290.0ms
# image 5/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/12.jpg: 640x640 1 polyp, 277.4ms
# image 6/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/13.jpg: 640x640 1 polyp, 321.6ms
# image 7/100 /content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG/test/images/14.jpg: 640x640 1 polyp, 321.0ms
# ...
