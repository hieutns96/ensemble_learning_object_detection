# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python -m pip install pyyaml==5.1
import sys, os, distutils.core
# Note: This is a faster way to install detectron2 in Colab, but it does not include all functionalities (e.g. compiled operators).
# See https://detectron2.readthedocs.io/tutorials/install.html for full installation instructions
# !git clone 'https://github.com/facebookresearch/detectron2'
dist = distutils.core.run_setup("./detectron2/setup.py")
# !python -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])}
sys.path.insert(0, os.path.abspath('./detectron2'))

# Properly install detectron2. (Please do not install twice in both ways)
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 5.8 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15792, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 15792 (delta 15), reused 31 (delta 10), pack-reused 15743 (from 1)
# Receiving objects: 100% (15792/15792), 6.36 MiB | 22.09 MiB/s, done.
# Resolving deltas: 100% (11511/11511), done.
# Ignoring dataclasses: markers 'python_version < "3.7"' don't match your environment
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (2.5.0)
# Collecting yacs>=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Collecting fvcore<0.1.6,>=0.1.5
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Collecting omegaconf<2.4,>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black
#   Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from yacs>=0.1.8) (6.0.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.4)
# Collecting portalocker (from iopath<0.1.10,>=0.1.7)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<2.4,>=2.1)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.1)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.1 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.4 MB/s eta 0:00:00
# Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.4 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fvcore, antlr4-python3-runtime
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61395 sha256=47bb5188a1e02b033b30b7a0586cb188bc890eb278bbfc02299704adb01baf3f
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=b972dfb79de26efe01365640f389ea99c2427cb2fd3d1d117535d73f93dbaf54
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.10.0 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.12.1 portalocker-2.10.1 yacs-0.1.8

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# torch:  2.4 ; cuda:  cu121
# detectron2: 0.6

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
im = cv2.imread("./input.jpg")
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
cfg = get_cfg()
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
outputs = predictor(im)
# Out:
# [10/17 15:11:27 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# model_final_f10217.pkl: 178MB [00:01, 133MB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8f0e669ecb17> in <cell line: 8>()
#       6 cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
#       7 predictor = DefaultPredictor(cfg)
# ----> 8 outputs = predictor(im)
#
# NameError: name 'im' is not defined

# %%
cd drive/MyDrive/Polyp/
# Out:
# /content/drive/MyDrive/Polyp

# %%
import os
import numpy as np
import json
from detectron2.structures import BoxMode
import itertools
import cv2
import xml.etree.ElementTree as ET
import glob

def get_polyp_dicts(base_dir):
    classes = ['polyp']  # Adjust class names as necessary
    image_path = os.path.join(base_dir, "images")
    annotation_path = os.path.join(base_dir, "labels")

    dataset_dicts = []

    for idx, filename in enumerate(os.listdir(annotation_path)):
        if not filename.endswith(".txt"):
            continue

        # Construct the full image path
        image_file = os.path.splitext(filename)[0] + ".jpg"  # Assuming image format is .jpg
        image_file_path = os.path.join(image_path, image_file)

        # Read image dimensions
        height, width = cv2.imread(image_file_path).shape[:2]

        # Read YOLO annotations
        with open(os.path.join(annotation_path, filename)) as f:
            lines = f.readlines()

        record = {
            "file_name": image_file_path,
            "image_id": os.path.splitext(filename)[0],  # Use image name as image_id, we will need for COCOEvaluator
            "height": height,
            "width": width,
            "annotations": []
        }

        for line in lines:
            class_id, x_center, y_center, bbox_width, bbox_height = map(float, line.strip().split())

            # Convert YOLO format to absolute coordinates
            x_center *= width
            y_center *= height
            bbox_width *= width
            bbox_height *= height

            # Calculate bounding box coordinates
            x1 = x_center - (bbox_width / 2)
            y1 = y_center - (bbox_height / 2)
            x2 = x_center + (bbox_width / 2)
            y2 = y_center + (bbox_height / 2)

            obj = {
                "bbox": [x1, y1, x2, y2],
                "bbox_mode": BoxMode.XYXY_ABS,
                "category_id": int(class_id),  # Assuming class_id is zero-based
                "iscrowd": 0
            }
            record["annotations"].append(obj)

        dataset_dicts.append(record)

    return dataset_dicts

# %%
from detectron2.data import detection_utils as utils
import detectron2.data.transforms as T
import copy
import torch

def custom_mapper(dataset_dict):
    dataset_dict = copy.deepcopy(dataset_dict)  # it will be modified by code below
    image = utils.read_image(dataset_dict["file_name"], format="BGR")
    transform_list = [
        T.Resize((800,600)),
        T.RandomBrightness(0.8, 1.8),
        T.RandomContrast(0.6, 1.3),
        T.RandomSaturation(0.8, 1.4),
        T.RandomRotation(angle=[180, 180]),
        T.RandomLighting(0.7),
        T.RandomFlip(prob=0.5, horizontal=False, vertical=True),
        T.RandomFlip(prob=0.5, horizontal=True, vertical=False),
    ]
    image, transforms = T.apply_transform_gens(transform_list, image)
    dataset_dict["image"] = torch.as_tensor(image.transpose(2, 0, 1).astype("float32"))

    annos = [
        utils.transform_instance_annotations(obj, transforms, image.shape[:2])
        for obj in dataset_dict.pop("annotations")
        if obj.get("iscrowd", 0) == 0
    ]
    instances = utils.annotations_to_instances(annos, image.shape[:2])
    dataset_dict["instances"] = utils.filter_empty_instances(instances)
    return dataset_dict

# %%
# Clear all registrations
DatasetCatalog.clear()
MetadataCatalog.clear()

# %%
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_test_loader, build_detection_train_loader
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

class CustomTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return build_detection_train_loader(cfg, mapper=custom_mapper)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR,"inference")
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

# %%
from detectron2.config import get_cfg, CfgNode
def add_custom_configs(cfg: CfgNode):
    _C = cfg
    _C.SOLVER.BEST_CHECKPOINTER = CfgNode({"ENABLED": True})  # Set to True to enable
    _C.SOLVER.BEST_CHECKPOINTER.METRIC = "bbox/AP75"  # Set your desired metric
    _C.SOLVER.BEST_CHECKPOINTER.MODE = "max"

# %%
dataset_path = "/content/drive/MyDrive/Polyp/Datasets/Kvasir-SEG"
classes = ['polyp']

for d in ["train", "validation", "test"]:
    DatasetCatalog.register("polyp_" + d, lambda d=d: get_polyp_dicts(os.path.join(dataset_path, d)))
    MetadataCatalog.get("polyp_" + d).set(thing_classes=classes)

metadata = MetadataCatalog.get("polyp_train")

# %%
dataset_dicts = DatasetCatalog.get('polyp_train')


for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=0.5)
    out = visualizer.draw_dataset_dict(d)
    cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=176x176>
# <PIL.Image.Image image mode=RGB size=176x176>
# <PIL.Image.Image image mode=RGB size=176x176>

# %%
from detectron2.engine import DefaultTrainer
from detectron2.engine import hooks

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("polyp_train",)
cfg.DATASETS.TEST = ("polyp_validation",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2  # This is the real "batch size" commonly known to deep learning people
cfg.SOLVER.MAX_ITER = 5000    # 300 iterations seems good enough for this toy dataset; you will need to train longer for a practical dataset
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ballon). (see https://detectron2.readthedocs.io/tutorials/datasets.html#update-the-config-for-new-datasets)
cfg.TEST.EVAL_PERIOD = 50
add_custom_configs(cfg)

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = CustomTrainer(cfg)

trainer.register_hooks([
  hooks.BestCheckpointer(
    cfg.TEST.EVAL_PERIOD,  # How often to evaluate
    trainer.checkpointer,
    cfg.SOLVER.BEST_CHECKPOINTER.METRIC,
    mode=cfg.SOLVER.BEST_CHECKPOINTER.MODE,
  )
])

trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [10/17 15:58:32 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [10/17 15:58:41 d2.data.build]: Removed 0 images with no usable annotations. 799 images left.
# [10/17 15:58:41 d2.data.build]: Using training sampler TrainingSampler
# [10/17 15:58:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 15:58:41 d2.data.common]: Serializing 799 elements to byte tensors and concatenating them all ...
# [10/17 15:58:41 d2.data.common]: Serialized dataset takes 0.23 MiB
# [10/17 15:58:41 d2.data.build]: Making batched data loader with batch_size=2
# [10/17 15:58:41 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [10/17 15:58:41 d2.engine.train_loop]: Starting training from iteration 0
# [10/17 15:58:48 d2.utils.events]:  eta: 0:26:51  iter: 19  total_loss: 0.4307  loss_cls: 0.2776  loss_box_reg: 0.1223  loss_rpn_cls: 0.008931  loss_rpn_loc: 0.005606    time: 0.3237  last_time: 0.3270  data_time: 0.0265  last_data_time: 0.0090   lr: 0.00039962  max_mem: 4769M
# [10/17 15:58:56 d2.utils.events]:  eta: 0:27:00  iter: 39  total_loss: 0.287  loss_cls: 0.134  loss_box_reg: 0.137  loss_rpn_cls: 0.00698  loss_rpn_loc: 0.004667    time: 0.3515  last_time: 0.4452  data_time: 0.0188  last_data_time: 0.0311   lr: 0.00079922  max_mem: 4769M
# [10/17 15:59:00 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 15:59:00 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 15:59:00 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 15:59:00 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 15:59:00 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 15:59:00 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 15:59:00 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 15:59:01 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0014 s/iter. Inference: 0.0790 s/iter. Eval: 0.0003 s/iter. Total: 0.0808 s/iter. ETA=0:00:07
# [10/17 15:59:06 d2.evaluation.evaluator]: Inference done 72/100. Dataloading: 0.0020 s/iter. Inference: 0.0802 s/iter. Eval: 0.0004 s/iter. Total: 0.0826 s/iter. ETA=0:00:02
# [10/17 15:59:09 d2.evaluation.evaluator]: Total inference time: 0:00:08.064797 (0.084893 s / iter per device, on 1 devices)
# [10/17 15:59:09 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.080737 s / iter per device, on 1 devices)
# [10/17 15:59:09 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 15:59:09 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 15:59:09 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.41s).
# Accumulating evaluation results...
# DONE (t=0.10s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.567
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.368
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.566
# [10/17 15:59:09 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 28.838 | 56.727 | 24.416 | 0.000 | 25.320 | 30.542 |
# [10/17 15:59:09 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 15:59:09 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 15:59:09 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 15:59:09 d2.evaluation.testing]: copypaste: 28.8380,56.7269,24.4159,0.0000,25.3201,30.5419
# [10/17 15:59:11 d2.engine.hooks]: Saved first model at 24.41588 @ 49 steps
# [10/17 15:59:14 d2.utils.events]:  eta: 0:27:07  iter: 59  total_loss: 0.2362  loss_cls: 0.08506  loss_box_reg: 0.1375  loss_rpn_cls: 0.0063  loss_rpn_loc: 0.004105    time: 0.3471  last_time: 0.3452  data_time: 0.0109  last_data_time: 0.0082   lr: 0.0011988  max_mem: 4769M
# [10/17 15:59:22 d2.utils.events]:  eta: 0:27:06  iter: 79  total_loss: 0.2067  loss_cls: 0.07346  loss_box_reg: 0.1267  loss_rpn_cls: 0.004057  loss_rpn_loc: 0.00332    time: 0.3538  last_time: 0.3823  data_time: 0.0137  last_data_time: 0.0188   lr: 0.0015984  max_mem: 4769M
# [10/17 15:59:30 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 15:59:30 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 15:59:30 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 15:59:30 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 15:59:30 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 15:59:30 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 15:59:30 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 15:59:31 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0015 s/iter. Inference: 0.0794 s/iter. Eval: 0.0003 s/iter. Total: 0.0812 s/iter. ETA=0:00:07
# [10/17 15:59:36 d2.evaluation.evaluator]: Inference done 73/100. Dataloading: 0.0018 s/iter. Inference: 0.0792 s/iter. Eval: 0.0003 s/iter. Total: 0.0813 s/iter. ETA=0:00:02
# [10/17 15:59:39 d2.evaluation.evaluator]: Total inference time: 0:00:07.942979 (0.083610 s / iter per device, on 1 devices)
# [10/17 15:59:39 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.079602 s / iter per device, on 1 devices)
# [10/17 15:59:39 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 15:59:39 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 15:59:39 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.11s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.600
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.604
# [10/17 15:59:39 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 32.335 | 59.977 | 36.221 | 0.000 | 28.742 | 34.949 |
# [10/17 15:59:39 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 15:59:39 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 15:59:39 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 15:59:39 d2.evaluation.testing]: copypaste: 32.3352,59.9773,36.2213,0.0000,28.7422,34.9490
# [10/17 15:59:39 d2.utils.events]:  eta: 0:27:10  iter: 99  total_loss: 0.2068  loss_cls: 0.07339  loss_box_reg: 0.1213  loss_rpn_cls: 0.00196  loss_rpn_loc: 0.003586    time: 0.3588  last_time: 0.3288  data_time: 0.0165  last_data_time: 0.0092   lr: 0.001998  max_mem: 4769M
# [10/17 15:59:41 d2.engine.hooks]: Saved best model as latest eval score for bbox/AP75 is 36.22134, better than last best score 24.41588 @ iteration 49.
# [10/17 15:59:48 d2.utils.events]:  eta: 0:27:01  iter: 119  total_loss: 0.1774  loss_cls: 0.07071  loss_box_reg: 0.0973  loss_rpn_cls: 0.002315  loss_rpn_loc: 0.004353    time: 0.3554  last_time: 0.3146  data_time: 0.0106  last_data_time: 0.0088   lr: 0.0023976  max_mem: 4769M
# [10/17 15:59:56 d2.utils.events]:  eta: 0:27:11  iter: 139  total_loss: 0.1778  loss_cls: 0.06848  loss_box_reg: 0.08618  loss_rpn_cls: 0.003653  loss_rpn_loc: 0.004251    time: 0.3621  last_time: 0.3912  data_time: 0.0189  last_data_time: 0.0096   lr: 0.0027972  max_mem: 4769M
# [10/17 16:00:00 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:00:00 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:00:00 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:00:00 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:00:00 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:00:00 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:00:00 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:00:01 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0030 s/iter. Inference: 0.0786 s/iter. Eval: 0.0003 s/iter. Total: 0.0819 s/iter. ETA=0:00:07
# [10/17 16:00:06 d2.evaluation.evaluator]: Inference done 73/100. Dataloading: 0.0020 s/iter. Inference: 0.0789 s/iter. Eval: 0.0003 s/iter. Total: 0.0813 s/iter. ETA=0:00:02
# [10/17 16:00:09 d2.evaluation.evaluator]: Total inference time: 0:00:07.831275 (0.082434 s / iter per device, on 1 devices)
# [10/17 16:00:09 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.079063 s / iter per device, on 1 devices)
# [10/17 16:00:09 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:00:09 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:00:09 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.321
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.567
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.461
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.626
# [10/17 16:00:09 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 32.106 | 56.693 | 32.005 | 0.000 | 31.991 | 35.727 |
# [10/17 16:00:09 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:00:09 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:00:09 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:00:09 d2.evaluation.testing]: copypaste: 32.1061,56.6933,32.0051,0.0000,31.9913,35.7270
# [10/17 16:00:09 d2.engine.hooks]: Not saving as latest eval score for bbox/AP75 is 32.00511, not better than best score 36.22134 @ iteration 99.
# [10/17 16:00:13 d2.utils.events]:  eta: 0:27:27  iter: 159  total_loss: 0.142  loss_cls: 0.05916  loss_box_reg: 0.07185  loss_rpn_cls: 0.002679  loss_rpn_loc: 0.004398    time: 0.3656  last_time: 0.3754  data_time: 0.0164  last_data_time: 0.0090   lr: 0.0031968  max_mem: 4769M
# [10/17 16:00:20 d2.utils.events]:  eta: 0:27:15  iter: 179  total_loss: 0.1535  loss_cls: 0.06672  loss_box_reg: 0.07253  loss_rpn_cls: 0.002244  loss_rpn_loc: 0.0045    time: 0.3629  last_time: 0.3449  data_time: 0.0113  last_data_time: 0.0096   lr: 0.0035964  max_mem: 4769M
# [10/17 16:00:28 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:00:28 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:00:28 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:00:28 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:00:28 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:00:28 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:00:28 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:00:29 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0014 s/iter. Inference: 0.0798 s/iter. Eval: 0.0003 s/iter. Total: 0.0816 s/iter. ETA=0:00:07
# [10/17 16:00:34 d2.evaluation.evaluator]: Inference done 73/100. Dataloading: 0.0019 s/iter. Inference: 0.0795 s/iter. Eval: 0.0003 s/iter. Total: 0.0818 s/iter. ETA=0:00:02
# [10/17 16:00:36 d2.evaluation.evaluator]: Total inference time: 0:00:07.821122 (0.082328 s / iter per device, on 1 devices)
# [10/17 16:00:36 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.079554 s / iter per device, on 1 devices)
# [10/17 16:00:36 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:00:36 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:00:36 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.693
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.293
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.442
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.470
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
# [10/17 16:00:36 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 40.448 | 69.307 | 48.316 | 0.000 | 29.333 | 44.249 |
# [10/17 16:00:36 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:00:36 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:00:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:00:36 d2.evaluation.testing]: copypaste: 40.4476,69.3069,48.3161,0.0000,29.3328,44.2493
# [10/17 16:00:36 d2.utils.events]:  eta: 0:27:04  iter: 199  total_loss: 0.137  loss_cls: 0.05576  loss_box_reg: 0.06552  loss_rpn_cls: 0.006444  loss_rpn_loc: 0.005071    time: 0.3626  last_time: 0.3715  data_time: 0.0167  last_data_time: 0.0258   lr: 0.003996  max_mem: 4769M
# [10/17 16:00:38 d2.engine.hooks]: Saved best model as latest eval score for bbox/AP75 is 48.31615, better than last best score 36.22134 @ iteration 99.
# [10/17 16:00:46 d2.utils.events]:  eta: 0:27:10  iter: 219  total_loss: 0.1195  loss_cls: 0.04891  loss_box_reg: 0.06834  loss_rpn_cls: 0.002283  loss_rpn_loc: 0.003649    time: 0.3655  last_time: 0.5027  data_time: 0.0170  last_data_time: 0.0431   lr: 0.0043956  max_mem: 4769M
# [10/17 16:00:52 d2.utils.events]:  eta: 0:26:56  iter: 239  total_loss: 0.11  loss_cls: 0.04529  loss_box_reg: 0.05636  loss_rpn_cls: 0.002716  loss_rpn_loc: 0.003772    time: 0.3637  last_time: 0.3286  data_time: 0.0117  last_data_time: 0.0088   lr: 0.0047952  max_mem: 4769M
# [10/17 16:00:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:00:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:00:57 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:00:57 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:00:57 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:00:57 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:00:57 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:00:58 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0097 s/iter. Inference: 0.0793 s/iter. Eval: 0.0004 s/iter. Total: 0.0894 s/iter. ETA=0:00:07
# [10/17 16:01:03 d2.evaluation.evaluator]: Inference done 70/100. Dataloading: 0.0030 s/iter. Inference: 0.0825 s/iter. Eval: 0.0003 s/iter. Total: 0.0860 s/iter. ETA=0:00:02
# [10/17 16:01:06 d2.evaluation.evaluator]: Total inference time: 0:00:08.072841 (0.084977 s / iter per device, on 1 devices)
# [10/17 16:01:06 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.081367 s / iter per device, on 1 devices)
# [10/17 16:01:06 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:01:06 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:01:06 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.477
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
# [10/17 16:01:06 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 44.884 | 71.307 | 50.652 | 0.000 | 37.376 | 48.244 |
# [10/17 16:01:06 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:01:06 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:01:06 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:01:06 d2.evaluation.testing]: copypaste: 44.8836,71.3066,50.6515,0.0000,37.3760,48.2444
# [10/17 16:01:07 d2.engine.hooks]: Saved best model as latest eval score for bbox/AP75 is 50.65153, better than last best score 48.31615 @ iteration 199.
# [10/17 16:01:10 d2.utils.events]:  eta: 0:26:47  iter: 259  total_loss: 0.1181  loss_cls: 0.0459  loss_box_reg: 0.06207  loss_rpn_cls: 0.002636  loss_rpn_loc: 0.004351    time: 0.3623  last_time: 0.3200  data_time: 0.0146  last_data_time: 0.0081   lr: 0.0051948  max_mem: 4769M
# [10/17 16:01:19 d2.utils.events]:  eta: 0:26:48  iter: 279  total_loss: 0.1306  loss_cls: 0.04972  loss_box_reg: 0.0697  loss_rpn_cls: 0.004999  loss_rpn_loc: 0.004202    time: 0.3668  last_time: 0.3894  data_time: 0.0207  last_data_time: 0.0085   lr: 0.0055944  max_mem: 4769M
# [10/17 16:01:26 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:01:26 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:01:26 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:01:26 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:01:26 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:01:26 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:01:26 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:01:27 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0024 s/iter. Inference: 0.0821 s/iter. Eval: 0.0004 s/iter. Total: 0.0849 s/iter. ETA=0:00:07
# [10/17 16:01:32 d2.evaluation.evaluator]: Inference done 69/100. Dataloading: 0.0037 s/iter. Inference: 0.0823 s/iter. Eval: 0.0004 s/iter. Total: 0.0866 s/iter. ETA=0:00:02
# [10/17 16:01:35 d2.evaluation.evaluator]: Total inference time: 0:00:08.160080 (0.085896 s / iter per device, on 1 devices)
# [10/17 16:01:35 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.081314 s / iter per device, on 1 devices)
# [10/17 16:01:35 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:01:35 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:01:35 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.784
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.538
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.677
# [10/17 16:01:35 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 49.758 | 78.432 | 55.320 | 0.000 | 32.665 | 56.542 |
# [10/17 16:01:35 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:01:35 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:01:35 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:01:35 d2.evaluation.testing]: copypaste: 49.7584,78.4324,55.3201,0.0000,32.6650,56.5421
# [10/17 16:01:35 d2.utils.events]:  eta: 0:26:33  iter: 299  total_loss: 0.1341  loss_cls: 0.05803  loss_box_reg: 0.07127  loss_rpn_cls: 0.00285  loss_rpn_loc: 0.004846    time: 0.3643  last_time: 0.3316  data_time: 0.0104  last_data_time: 0.0080   lr: 0.005994  max_mem: 4769M
# [10/17 16:01:37 d2.engine.hooks]: Saved best model as latest eval score for bbox/AP75 is 55.32005, better than last best score 50.65153 @ iteration 249.
# [10/17 16:01:43 d2.utils.events]:  eta: 0:26:16  iter: 319  total_loss: 0.1054  loss_cls: 0.04096  loss_box_reg: 0.06064  loss_rpn_cls: 0.002004  loss_rpn_loc: 0.004325    time: 0.3626  last_time: 0.4004  data_time: 0.0113  last_data_time: 0.0087   lr: 0.0063936  max_mem: 4769M
# [10/17 16:01:52 d2.utils.events]:  eta: 0:26:14  iter: 339  total_loss: 0.1283  loss_cls: 0.05598  loss_box_reg: 0.05781  loss_rpn_cls: 0.001335  loss_rpn_loc: 0.00359    time: 0.3660  last_time: 0.3163  data_time: 0.0166  last_data_time: 0.0083   lr: 0.0067932  max_mem: 4769M
# [10/17 16:01:56 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:01:56 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:01:56 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:01:56 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:01:56 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:01:56 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:01:56 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:01:57 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0015 s/iter. Inference: 0.0799 s/iter. Eval: 0.0003 s/iter. Total: 0.0817 s/iter. ETA=0:00:07
# [10/17 16:02:02 d2.evaluation.evaluator]: Inference done 70/100. Dataloading: 0.0031 s/iter. Inference: 0.0810 s/iter. Eval: 0.0003 s/iter. Total: 0.0846 s/iter. ETA=0:00:02
# [10/17 16:02:05 d2.evaluation.evaluator]: Total inference time: 0:00:08.150476 (0.085794 s / iter per device, on 1 devices)
# [10/17 16:02:05 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.081186 s / iter per device, on 1 devices)
# [10/17 16:02:05 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:02:05 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:02:05 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.450
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.732
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.392
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.653
# [10/17 16:02:05 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 44.953 | 73.218 | 47.605 | 0.000 | 39.153 | 49.012 |
# [10/17 16:02:05 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:02:05 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:02:05 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:02:05 d2.evaluation.testing]: copypaste: 44.9535,73.2185,47.6048,0.0000,39.1528,49.0125
# [10/17 16:02:05 d2.engine.hooks]: Not saving as latest eval score for bbox/AP75 is 47.60479, not better than best score 55.32005 @ iteration 299.
# [10/17 16:02:08 d2.utils.events]:  eta: 0:26:01  iter: 359  total_loss: 0.1168  loss_cls: 0.04585  loss_box_reg: 0.05728  loss_rpn_cls: 0.004026  loss_rpn_loc: 0.003183    time: 0.3639  last_time: 0.3289  data_time: 0.0126  last_data_time: 0.0175   lr: 0.0071928  max_mem: 4769M
# [10/17 16:02:15 d2.utils.events]:  eta: 0:25:53  iter: 379  total_loss: 0.1209  loss_cls: 0.04628  loss_box_reg: 0.0635  loss_rpn_cls: 0.003125  loss_rpn_loc: 0.003727    time: 0.3623  last_time: 0.3795  data_time: 0.0129  last_data_time: 0.0266   lr: 0.0075924  max_mem: 4769M
# [10/17 16:02:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:02:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:02:23 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:02:23 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:02:23 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:02:23 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:02:23 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:02:24 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0015 s/iter. Inference: 0.0797 s/iter. Eval: 0.0003 s/iter. Total: 0.0815 s/iter. ETA=0:00:07
# [10/17 16:02:29 d2.evaluation.evaluator]: Inference done 73/100. Dataloading: 0.0017 s/iter. Inference: 0.0794 s/iter. Eval: 0.0003 s/iter. Total: 0.0815 s/iter. ETA=0:00:02
# [10/17 16:02:32 d2.evaluation.evaluator]: Total inference time: 0:00:07.957204 (0.083760 s / iter per device, on 1 devices)
# [10/17 16:02:32 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.079679 s / iter per device, on 1 devices)
# [10/17 16:02:32 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:02:32 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:02:32 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.411
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.697
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.358
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.449
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
# [10/17 16:02:32 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# ...
# [10/17 16:43:24 d2.evaluation.evaluator]: Total inference time: 0:00:07.881117 (0.082959 s / iter per device, on 1 devices)
# [10/17 16:43:24 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.080022 s / iter per device, on 1 devices)
# [10/17 16:43:24 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:43:24 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:43:24 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.660
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.590
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.590
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
# [10/17 16:43:24 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 56.529 | 89.641 | 66.022 | 4.000 | 48.792 | 58.995 |
# [10/17 16:43:24 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:43:24 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:43:24 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:43:24 d2.evaluation.testing]: copypaste: 56.5288,89.6408,66.0215,4.0000,48.7919,58.9951
# [10/17 16:43:24 d2.engine.hooks]: Not saving as latest eval score for bbox/AP75 is 66.02152, not better than best score 67.63273 @ iteration 2699.
# [10/17 16:43:27 d2.utils.events]:  eta: 0:00:46  iter: 4859  total_loss: 0.07422  loss_cls: 0.02707  loss_box_reg: 0.03889  loss_rpn_cls: 0.001111  loss_rpn_loc: 0.003859    time: 0.3565  last_time: 0.3900  data_time: 0.0138  last_data_time: 0.0110   lr: 0.02  max_mem: 4771M
# [10/17 16:43:35 d2.utils.events]:  eta: 0:00:40  iter: 4879  total_loss: 0.0781  loss_cls: 0.02593  loss_box_reg: 0.04564  loss_rpn_cls: 0.0009651  loss_rpn_loc: 0.004762    time: 0.3566  last_time: 0.3437  data_time: 0.0214  last_data_time: 0.0108   lr: 0.02  max_mem: 4771M
# [10/17 16:43:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:43:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:43:42 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:43:42 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:43:42 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:43:42 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:43:42 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:43:43 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0096 s/iter. Inference: 0.0792 s/iter. Eval: 0.0004 s/iter. Total: 0.0892 s/iter. ETA=0:00:07
# [10/17 16:43:48 d2.evaluation.evaluator]: Inference done 67/100. Dataloading: 0.0078 s/iter. Inference: 0.0813 s/iter. Eval: 0.0004 s/iter. Total: 0.0897 s/iter. ETA=0:00:02
# [10/17 16:43:51 d2.evaluation.evaluator]: Total inference time: 0:00:08.330088 (0.087685 s / iter per device, on 1 devices)
# [10/17 16:43:51 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.080664 s / iter per device, on 1 devices)
# [10/17 16:43:51 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:43:51 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:43:51 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.868
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.587
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.695
# [10/17 16:43:51 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 53.416 | 86.767 | 58.725 | 0.000 | 44.002 | 58.204 |
# [10/17 16:43:51 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:43:51 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:43:51 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:43:51 d2.evaluation.testing]: copypaste: 53.4165,86.7672,58.7254,0.0000,44.0015,58.2037
# [10/17 16:43:51 d2.utils.events]:  eta: 0:00:33  iter: 4899  total_loss: 0.05985  loss_cls: 0.0201  loss_box_reg: 0.03899  loss_rpn_cls: 0.0003929  loss_rpn_loc: 0.003182    time: 0.3565  last_time: 0.3205  data_time: 0.0130  last_data_time: 0.0112   lr: 0.02  max_mem: 4771M
# [10/17 16:43:51 d2.engine.hooks]: Not saving as latest eval score for bbox/AP75 is 58.72543, not better than best score 67.63273 @ iteration 2699.
# [10/17 16:43:58 d2.utils.events]:  eta: 0:00:26  iter: 4919  total_loss: 0.07106  loss_cls: 0.02567  loss_box_reg: 0.04016  loss_rpn_cls: 0.0005946  loss_rpn_loc: 0.004166    time: 0.3564  last_time: 0.3294  data_time: 0.0114  last_data_time: 0.0092   lr: 0.02  max_mem: 4771M
# [10/17 16:44:06 d2.utils.events]:  eta: 0:00:20  iter: 4939  total_loss: 0.076  loss_cls: 0.02635  loss_box_reg: 0.04569  loss_rpn_cls: 0.0008416  loss_rpn_loc: 0.003718    time: 0.3565  last_time: 0.3277  data_time: 0.0158  last_data_time: 0.0090   lr: 0.02  max_mem: 4771M
# [10/17 16:44:10 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:44:10 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:44:10 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:44:10 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:44:10 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:44:10 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:44:10 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:44:11 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0014 s/iter. Inference: 0.0792 s/iter. Eval: 0.0003 s/iter. Total: 0.0809 s/iter. ETA=0:00:07
# [10/17 16:44:16 d2.evaluation.evaluator]: Inference done 72/100. Dataloading: 0.0034 s/iter. Inference: 0.0793 s/iter. Eval: 0.0003 s/iter. Total: 0.0831 s/iter. ETA=0:00:02
# [10/17 16:44:18 d2.evaluation.evaluator]: Total inference time: 0:00:08.051365 (0.084751 s / iter per device, on 1 devices)
# [10/17 16:44:18 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:07 (0.080067 s / iter per device, on 1 devices)
# [10/17 16:44:18 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:44:18 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:44:18 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.895
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.626
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.599
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
# [10/17 16:44:18 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 57.236 | 89.544 | 62.565 | 0.000 | 47.729 | 61.863 |
# [10/17 16:44:18 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:44:18 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:44:18 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:44:18 d2.evaluation.testing]: copypaste: 57.2356,89.5441,62.5648,0.0000,47.7295,61.8630
# [10/17 16:44:18 d2.engine.hooks]: Not saving as latest eval score for bbox/AP75 is 62.56483, not better than best score 67.63273 @ iteration 2699.
# [10/17 16:44:22 d2.utils.events]:  eta: 0:00:13  iter: 4959  total_loss: 0.06512  loss_cls: 0.02152  loss_box_reg: 0.03836  loss_rpn_cls: 0.000734  loss_rpn_loc: 0.003926    time: 0.3565  last_time: 0.3211  data_time: 0.0154  last_data_time: 0.0088   lr: 0.02  max_mem: 4771M
# [10/17 16:44:29 d2.utils.events]:  eta: 0:00:06  iter: 4979  total_loss: 0.06527  loss_cls: 0.02179  loss_box_reg: 0.03862  loss_rpn_cls: 0.0007946  loss_rpn_loc: 0.003588    time: 0.3564  last_time: 0.3308  data_time: 0.0128  last_data_time: 0.0120   lr: 0.02  max_mem: 4771M
# [10/17 16:44:42 d2.utils.events]:  eta: 0:00:00  iter: 4999  total_loss: 0.06543  loss_cls: 0.02314  loss_box_reg: 0.03315  loss_rpn_cls: 0.00086  loss_rpn_loc: 0.003666    time: 0.3565  last_time: 0.3232  data_time: 0.0142  last_data_time: 0.0098   lr: 0.02  max_mem: 4771M
# [10/17 16:44:43 d2.engine.hooks]: Overall training speed: 4998 iterations in 0:29:42 (0.3565 s / it)
# [10/17 16:44:43 d2.engine.hooks]: Total training time: 0:46:00 (0:16:18 on hooks)
# [10/17 16:44:44 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:44:44 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:44:44 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:44:44 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:44:44 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [10/17 16:44:44 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [10/17 16:44:44 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:44:45 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0014 s/iter. Inference: 0.0780 s/iter. Eval: 0.0003 s/iter. Total: 0.0796 s/iter. ETA=0:00:07
# [10/17 16:44:50 d2.evaluation.evaluator]: Inference done 51/100. Dataloading: 0.0072 s/iter. Inference: 0.1116 s/iter. Eval: 0.0008 s/iter. Total: 0.1197 s/iter. ETA=0:00:05
# [10/17 16:44:55 d2.evaluation.evaluator]: Inference done 99/100. Dataloading: 0.0061 s/iter. Inference: 0.1054 s/iter. Eval: 0.0008 s/iter. Total: 0.1125 s/iter. ETA=0:00:00
# [10/17 16:44:55 d2.evaluation.evaluator]: Total inference time: 0:00:10.711992 (0.112758 s / iter per device, on 1 devices)
# [10/17 16:44:55 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:09 (0.105128 s / iter per device, on 1 devices)
# [10/17 16:44:55 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [10/17 16:44:55 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/coco_instances_results.json
# [10/17 16:44:55 d2.evaluation.coco_evaluation]: Evaluating predictions with official COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.545
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.614
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.645
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.645
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.596
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.661
# [10/17 16:44:55 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 54.459 | 88.459 | 61.391 | 0.000 | 45.360 | 58.716 |
# [10/17 16:44:55 d2.engine.defaults]: Evaluation results for polyp_validation in csv format:
# [10/17 16:44:55 d2.evaluation.testing]: copypaste: Task: bbox
# [10/17 16:44:55 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [10/17 16:44:55 d2.evaluation.testing]: copypaste: 54.4586,88.4589,61.3907,0.0000,45.3603,58.7161
# [10/17 16:44:55 d2.engine.hooks]: Not saving as latest eval score for bbox/AP75 is 61.39072, not better than best score 67.63273 @ iteration 2699.

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_best.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
cfg.DATASETS.TEST = ("polyp_test", )
predictor = DefaultPredictor(cfg)
# Out:
# [10/17 16:45:46 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_best.pth ...
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))

# %%
from detectron2.utils.visualizer import ColorMode
import random
import matplotlib.pyplot as plt

dataset_dicts = DatasetCatalog.get('polyp_test')
for d in random.sample(dataset_dicts, 3):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1], metadata=metadata, scale=0.8)
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure(figsize = (14, 10))
    plt.imshow(cv2.cvtColor(v.get_image()[:, :, ::-1], cv2.COLOR_BGR2RGB))
    plt.show()

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

evaluator = COCOEvaluator("polyp_test", ("bbox",), False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "polyp_test")
print(inference_on_dataset(predictor.model, val_loader, evaluator))
# Out:
# [10/17 16:46:40 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# [10/17 16:46:40 d2.evaluation.coco_evaluation]: Trying to convert 'polyp_test' to COCO format ...
# [10/17 16:46:40 d2.data.datasets.coco]: Converting annotations of dataset 'polyp_test' to COCO format ...)
# [10/17 16:46:40 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [10/17 16:46:40 d2.data.datasets.coco]: Conversion finished, #images: 100, #annotations: 101
# [10/17 16:46:40 d2.data.datasets.coco]: Caching COCO format annotations at './output/polyp_test_coco_format.json' ...
# [10/17 16:46:41 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   polyp    | 101          |
# |            |              |
# [10/17 16:46:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/17 16:46:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/17 16:46:41 d2.data.common]: Serializing 100 elements to byte tensors and concatenating them all ...
# [10/17 16:46:41 d2.data.common]: Serialized dataset takes 0.03 MiB
# [10/17 16:46:41 d2.evaluation.evaluator]: Start inference on 100 batches
# [10/17 16:46:42 d2.evaluation.evaluator]: Inference done 11/100. Dataloading: 0.0014 s/iter. Inference: 0.0793 s/iter. Eval: 0.0002 s/iter. Total: 0.0810 s/iter. ETA=0:00:07
